# %% [markdown]
# **Objectives**
#
# In this lab, we will
#
# 1. Know basic use of Pandas.
#
# 2. Understand what are re-identification attack, reconstruction attack and differential attack.
#
# 3. Understand how to implement these attack methods.
#
# # Basic use of Pandas
#
# ## What is Pandas?
#
# **pandas** is a Python package providing fast, flexible, and expressive data structures designed to make working with "relational" or "labeled" data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, **real world** data analysis in Python. Additionally, it has the broader goal of becoming **the most powerful and flexible open source data analysis / manipulation tool available in any language**. It is already well on its way toward this goal.
#
# ## Import Pandas
#
# Importing a library means loading it into the memory and then it’s there for you to work with. In order to import Pandas all you have to do is run the following code:

# %%
import pandas as pd # import the Pandas library
import numpy as np

# %% [markdown]
# ## Constructa dictionary
#
# Example:
#
#     data = {'First Column Name':  ['First value', 'Second value',...],
#
#         'Second Column Name': ['First value', 'Second value',...],
#          ....
#          }

# %%
data = {'Name': ['Alice', 'Betty', 'Charles', 'David', 'Emily', 'Fred'],
       'Zipcode': [47677, 47602, 47678, 47905, 47909, 47906],
       'Age': [29, 22, 27, 43, 42, 47],
       'Sex': ['F', 'F', 'M', 'M', 'F', 'M'],
       'Disease': ['Ovarian Cancer', 'Ovarian Cancer',
                   'Prostate Cancer', 'Flu', 'Heart Disease', 'Heart Disease']}

# %% [markdown]
# ## Create a dataframe from dictionary
#
# In order to convert a certain Python object (dictionary, lists etc) the basic command is:
#
#     pd.DataFrame()
#
# Two-dimensional size-mutable, potentially heterogeneous tabular data
# structure with labeled axes (rows and columns).

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Zipcode  Age Sex          Disease
# 0    Alice    47677   29   F   Ovarian Cancer
# 1    Betty    47602   22   F   Ovarian Cancer
# 2  Charles    47678   27   M  Prostate Cancer
# 3    David    47905   43   M              Flu
# 4    Emily    47909   42   F    Heart Disease
# 5     Fred    47906   47   M    Heart Disease

# %% [markdown]
# ## View and inspect data
#
#
# 1. Get the first n rows

# %%
df.head(5)
# Out:
#       Name  Zipcode  Age Sex          Disease
# 0    Alice    47677   29   F   Ovarian Cancer
# 1    Betty    47602   22   F   Ovarian Cancer
# 2  Charles    47678   27   M  Prostate Cancer
# 3    David    47905   43   M              Flu
# 4    Emily    47909   42   F    Heart Disease

# %% [markdown]
# 2. Get the last n rows

# %%
df.tail(3)
# Out:
#     Name  Zipcode  Age Sex        Disease
# 3  David    47905   43   M            Flu
# 4  Emily    47909   42   F  Heart Disease
# 5   Fred    47906   47   M  Heart Disease

# %% [markdown]
# 3. Ger the number of rows and columns

# %%
df.shape
# Out:
# (6, 5)

# %% [markdown]
# 4. Get the index, datatype and memory information.

# %%
df.info
# Out:
# <bound method DataFrame.info of       Name  Zipcode  Age Sex          Disease
# 0    Alice    47677   29   F   Ovarian Cancer
# 1    Betty    47602   22   F   Ovarian Cancer
# 2  Charles    47678   27   M  Prostate Cancer
# 3    David    47905   43   M              Flu
# 4    Emily    47909   42   F    Heart Disease
# 5     Fred    47906   47   M    Heart Disease>

# %% [markdown]
# 5. Get the mean of all columns

# %%
df.mean(numeric_only=True)
# Out:
# Zipcode    47779.5
# Age           35.0
# dtype: float64

# %% [markdown]
# 6. Get the correlation between columns in a data frame

# %%
df.corr(numeric_only=True)
# Out:
#           Zipcode       Age
# Zipcode  1.000000  0.983538
# Age      0.983538  1.000000

# %% [markdown]
# 7. Get the highest value in each column

# %%
df.max()
# Out:
# Name                  Fred
# Zipcode              47909
# Age                     47
# Sex                      M
# Disease    Prostate Cancer
# dtype: object

# %% [markdown]
# ## Selection of Data
#
# 1. Select columns

# %%
df['Sex']
# Out:
# 0    F
# 1    F
# 2    M
# 3    M
# 4    F
# 5    M
# Name: Sex, dtype: object

# %%
df[['Age','Sex']]
# Out:
#    Age Sex
# 0   29   F
# 1   22   F
# 2   27   M
# 3   43   M
# 4   42   F
# 5   47   M

# %% [markdown]
# 2. Select rows by position

# %%
df.iloc[0]
# Out:
# Name                Alice
# Zipcode             47677
# Age                    29
# Sex                     F
# Disease    Ovarian Cancer
# Name: 0, dtype: object

# %%
df.iloc[:3]
# Out:
#       Name  Zipcode  Age Sex          Disease
# 0    Alice    47677   29   F   Ovarian Cancer
# 1    Betty    47602   22   F   Ovarian Cancer
# 2  Charles    47678   27   M  Prostate Cancer

# %% [markdown]
# 3. Select an element

# %%
df.iloc[0,0]
# Out:
# 'Alice'

# %% [markdown]
# 4. Select rows by index

# %%
df.loc[0]
# Out:
# Name                Alice
# Zipcode             47677
# Age                    29
# Sex                     F
# Disease    Ovarian Cancer
# Name: 0, dtype: object

# %%
df.loc[:3]
# Out:
#       Name  Zipcode  Age Sex          Disease
# 0    Alice    47677   29   F   Ovarian Cancer
# 1    Betty    47602   22   F   Ovarian Cancer
# 2  Charles    47678   27   M  Prostate Cancer
# 3    David    47905   43   M              Flu

# %%
df.loc[0,'Name']
# Out:
# 'Alice'

# %% [markdown]
# 5. Replace values with different values
#
# Replace values given in `to_replace` with `value`. Values of the DataFrame are replaced with other values dynamically.
#
#     df.replace(to_replace=None, value=None, inplace=False)

# %%
df.replace('Flu','Lung Cancer')
# Out:
#       Name  Zipcode  Age Sex          Disease
# 0    Alice    47677   29   F   Ovarian Cancer
# 1    Betty    47602   22   F   Ovarian Cancer
# 2  Charles    47678   27   M  Prostate Cancer
# 3    David    47905   43   M      Lung Cancer
# 4    Emily    47909   42   F    Heart Disease
# 5     Fred    47906   47   M    Heart Disease

# %% [markdown]
# # Implementation of Re-identification / De-anonymisation
#
# ## Linkage Attack
#
# We now create a small dataset and see how to implement a linkage attack. We follow the mini dataset from the former introduction.

# %%
data = {'Name': ['Alice', 'Betty', 'Charles', 'David', 'Emily', 'Fred',
'Tom', 'Alex', 'Vincent', 'Serena'],
'Zipcode': [47677, 47602, 47678, 47905, 47909, 47906,
47433,47489,47422,47443],
'Age': [29, 22, 27, 43, 42, 47,
32,33,34,38],
'Sex': ['F', 'F', 'M', 'M', 'F', 'M',
'M', 'M', 'M', 'F'],
'Disease': ['Ovarian Cancer', 'Ovarian Cancer',
'Prostate Cancer', 'Flu', 'Heart Disease', 'Heart Disease',
'Flu', 'Flu', 'Flu', 'Heart Disease']}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Zipcode  Age Sex          Disease
# 0    Alice    47677   29   F   Ovarian Cancer
# 1    Betty    47602   22   F   Ovarian Cancer
# 2  Charles    47678   27   M  Prostate Cancer
# 3    David    47905   43   M              Flu
# 4    Emily    47909   42   F    Heart Disease
# 5     Fred    47906   47   M    Heart Disease
# 6      Tom    47433   32   M              Flu
# 7     Alex    47489   33   M              Flu
# 8  Vincent    47422   34   M              Flu
# 9   Serena    47443   38   F    Heart Disease

# %% [markdown]
# Firstly, we remove its key attribute "name",

# %%
data1 = {'Zipcode': [47677, 47602, 47678, 47905, 47909, 47906,
47433,47489,47422,47443],
'Age': [29, 22, 27, 43, 42, 47,
32,33,34,38],
'Sex': ['F', 'F', 'M', 'M', 'F', 'M',
'M', 'M', 'M', 'F'],
'Disease': ['Ovarian Cancer', 'Ovarian Cancer',
'Prostate Cancer', 'Flu', 'Heart Disease', 'Heart Disease',
'Flu', 'Flu', 'Flu', 'Heart Disease']}

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#    Zipcode  Age Sex          Disease
# 0    47677   29   F   Ovarian Cancer
# 1    47602   22   F   Ovarian Cancer
# 2    47678   27   M  Prostate Cancer
# 3    47905   43   M              Flu
# 4    47909   42   F    Heart Disease
# 5    47906   47   M    Heart Disease
# 6    47433   32   M              Flu
# 7    47489   33   M              Flu
# 8    47422   34   M              Flu
# 9    47443   38   F    Heart Disease

# %% [markdown]
# Secondly, we remove its sensitive attribute "Disease" as the second dataset

# %%
data2 = {'Name': ['Alice', 'Betty', 'Charles', 'David', 'Emily', 'Fred',
'Tom', 'Alex', 'Vincent', 'Serena'],
'Zipcode': [47677, 47602, 47678, 47905, 47909, 47906,
47433,47489,47422,47443],
'Age': [29, 22, 27, 43, 42, 47,
32,33,34,38],
'Sex': ['F', 'F', 'M', 'M', 'F', 'M',
'M', 'M', 'M', 'F']}

# %%
df2 = pd.DataFrame(data2)
df2
# Out:
#       Name  Zipcode  Age Sex
# 0    Alice    47677   29   F
# 1    Betty    47602   22   F
# 2  Charles    47678   27   M
# 3    David    47905   43   M
# 4    Emily    47909   42   F
# 5     Fred    47906   47   M
# 6      Tom    47433   32   M
# 7     Alex    47489   33   M
# 8  Vincent    47422   34   M
# 9   Serena    47443   38   F

# %% [markdown]
# So when an adversary has both datasets, the adversary may re-identify that "Alice" and "Betty" have "Ovarian Cancer", "Charies" has "Prostate Cancer", and so on by link the information of df1 and df2.

# %%
data = {'Name': ['Alice', 'Betty', 'Charles', 'David', 'Emily', 'Fred',
'Tom', 'Alex', 'Vincent', 'Serena'],
'Zipcode': [47677, 47602, 47678, 47905, 47909, 47906,
47433,47489,47422,47443],
'Age': [29, 22, 27, 43, 42, 47,
32,33,34,38],
'Sex': ['F', 'F', 'M', 'M', 'F', 'M',
'M', 'M', 'M', 'F'],
'Disease': ['Ovarian Cancer', 'Ovarian Cancer',
'Prostate Cancer', 'Flu', 'Heart Disease', 'Heart Disease',
'Flu', 'Flu', 'Flu', 'Heart Disease']}


df = pd.DataFrame(data)
df
# Out:
#       Name  Zipcode  Age Sex          Disease
# 0    Alice    47677   29   F   Ovarian Cancer
# 1    Betty    47602   22   F   Ovarian Cancer
# 2  Charles    47678   27   M  Prostate Cancer
# 3    David    47905   43   M              Flu
# 4    Emily    47909   42   F    Heart Disease
# 5     Fred    47906   47   M    Heart Disease
# 6      Tom    47433   32   M              Flu
# 7     Alex    47489   33   M              Flu
# 8  Vincent    47422   34   M              Flu
# 9   Serena    47443   38   F    Heart Disease

# %% [markdown]
# ## Unsorted Matching Attack
#
# Now, let's create three datasets to see how to implement unsorted matching attack.

# %%
data_unsorted1 = {"Sex": ["Female", "Female", "Female", "Female", "Female", "Female", "Male", "Male", "Male", "Male", "Male"],
                  "ZIP": ['02138', '02139', '02141', '02142', '02138', '02139', '02141', '02142', '02138','02139', '02141']}

# %%
df3 = pd.DataFrame(data_unsorted1)
df3
# Out:
#        Sex    ZIP
# 0   Female  02138
# 1   Female  02139
# 2   Female  02141
# 3   Female  02142
# 4   Female  02138
# 5   Female  02139
# 6     Male  02141
# 7     Male  02142
# 8     Male  02138
# 9     Male  02139
# 10    Male  02141

# %% [markdown]
# Now, let's build the second dataset of these three, We anonymise its first attribute "Sex".

# %%
data_unsorted2 = {"Sex" : ["Person", "Person", "Person", "Person", "Person", "Person", "Person", "Person", "Person", "Person", "Person"],
                  "ZIP" : ['02138', '02139', '02141', '02142', '02138', '02139', '02141', '02142', '02138', '02139', '02141']}

# %%
df4 = pd.DataFrame(data_unsorted2)
df4
# Out:
#        Sex    ZIP
# 0   Person  02138
# 1   Person  02139
# 2   Person  02141
# 3   Person  02142
# 4   Person  02138
# 5   Person  02139
# 6   Person  02141
# 7   Person  02142
# 8   Person  02138
# 9   Person  02139
# 10  Person  02141

# %% [markdown]
# Now, let's build the third dataset of these three. We anonymise its second attribute "ZIP".

# %%
data_unsorted3 = {"Sex" : ["Female", "Female", "Female", "Female", "Female", "Female", "Male", "Male", "Male", "Male", "Male"],
                  "ZIP" : ['02130', '02130', '02140', '02140', '02130', '02130', '02140', '02140', '02130', '02130', '02140']}

# %%
df5 = pd.DataFrame(data_unsorted3)
df5
# Out:
#        Sex    ZIP
# 0   Female  02130
# 1   Female  02130
# 2   Female  02140
# 3   Female  02140
# 4   Female  02130
# 5   Female  02130
# 6     Male  02140
# 7     Male  02140
# 8     Male  02130
# 9     Male  02130
# 10    Male  02140

# %% [markdown]
# Only based on df4 and df5, we can infer the information of df3, shown as follows.

# %%
data_unsorted4 = {"Sex4" : ["Person", "Person", "Person", "Person", "Person","Person" , "Person", "Person", "Person", "Person", "Person"],
                  "ZIP4" : ["02138" , "02139" , "02141" , "02142" , "02138" , "02139" , "02141" , "02142" , "02138" , "02139" , "02141" ],
                  "Sex5" : ["Female", "Female", "Female", "Female", "Female", "Female", "Male"  , "Male"  , "Male"  , "Male"  , "Male"  ],
                  "ZIP5" : ["02130" , "02130" , "02140" , "02140" , "02130" , "02130" , "02140" , "02140" , "02130" , "02130" , "02140" ],
                  "Sex6" : ["Female", "Female", "Female", "Female", "Female", "Female", "Male"  , "Male"  , "Male"  , "Male"  , "Male"  ],
                  "ZIP6" : ["02138" , "02139" , "02141" , "02142" , "02138" , "02139" , "02141" , "02142" , "02138" , "02139" , "02141" ]}

# %%
df6 = pd.DataFrame(data_unsorted4)
df6
# Out:
#       Sex4   ZIP4    Sex5   ZIP5    Sex6   ZIP6
# 0   Person  02138  Female  02130  Female  02138
# 1   Person  02139  Female  02130  Female  02139
# 2   Person  02141  Female  02140  Female  02141
# 3   Person  02142  Female  02140  Female  02142
# 4   Person  02138  Female  02130  Female  02138
# 5   Person  02139  Female  02130  Female  02139
# 6   Person  02141    Male  02140    Male  02141
# 7   Person  02142    Male  02140    Male  02142
# 8   Person  02138    Male  02130    Male  02138
# 9   Person  02139    Male  02130    Male  02139
# 10  Person  02141    Male  02140    Male  02141

# %% [markdown]
# # Differential Attack
#
# Now we will implement differential attack using the example introduced in the lecture. Firstly, we create a raw dataset without any anonymity.

# %%
data_da = {"Name" : ["Alice", "Bob", "Chris", "David", "Eric", "Fiona", "Grace"],
           "Grade" : [85  , 62 , 70, 93 , 58, 81 , 74]}

# %%
df8 = pd.DataFrame(data_da)
df8
# Out:
#     Name  Grade
# 0  Alice     85
# 1    Bob     62
# 2  Chris     70
# 3  David     93
# 4   Eric     58
# 5  Fiona     81
# 6  Grace     74

# %% [markdown]
# When we consider the attribute 'Grade' is sensitive, the dataset is anonymised as following:

# %%
data_da1 = {"Name" : ["Alice", "Bob", "Chris", "David", "Eric", "Fiona", "Grace"],
"Grade" : ["**", "**", "**", "**", "**", "**", "**"]}

# %%
df9 = pd.DataFrame(data_da1)
df9
# Out:
#     Name Grade
# 0  Alice    **
# 1    Bob    **
# 2  Chris    **
# 3  David    **
# 4   Eric    **
# 5  Fiona    **
# 6  Grace    **

# %% [markdown]
# However, we can still query about the raw dataset, for example, we want to know the sum of all students' grade, it will return the result to us.

# %%
df8['Grade'].sum()
# Out:
# 523

# %% [markdown]
# We know that the sum of all students' grade is 523. Now, we will query about the sum of the first 6 students' grade except Grace, it will retuern the result to us.

# %%
df8['Grade'].sum() - df8['Grade'][6]
# Out:
# 449

# %% [markdown]
# Now, we can use the first query answer to subtract the second query answer to get Grace's grade

# %%
523 - 449
# Out:
# 74

# %% [markdown]
# It returns Grace's grade is 74.

# %% [markdown]
# # Conclusion
#
# In this lab, we learnt:
#
# 1. Pandas and DataFrame;
#
# 2. How to build a dataframe and show the dataset;
#
# 3. Re-identification attack, re-construction attacks and differential attack.
